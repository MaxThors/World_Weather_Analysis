# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 744

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c9ed5714189687454c27c9cc55e769bb

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_weather = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_current_weather})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bluff
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | presque isle
# Processing Record 5 of Set 1 | butaritari
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | east london
# Processing Record 8 of Set 1 | sakakah
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | hobart
# Processing Record 11 of Set 1 | port lincoln
# Processing Record 12 of Set 1 | barrow
# Processing Record 13 of Set 1 | andra
# Processing Record 14 of Set 1 | lincoln
# Processing Record 15 of Set 1 | sibenik
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | atuona
# Processing Record 18 of Set 1 | ushtobe
# Processing Record 19 of Set 1 | hermanus
# Processing Record 20 of Set 1 | port alfred
# Processing Record 21 of Set 1 | avera
# Processing Record 22 of Set 1 | dikson
# Processing Record 23 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 1 | ilebo
# Processing Record 25 of Set 1 | touros
# Processing Record 26 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 1 | gudalur
# Processing Record 29 of Set 1 | new norfolk
# Processing Record 30 of Set 1 | talnakh
# Processing Record 31 of Set 1 | punta arenas
# Processing Record 32 of Set 1 | qaanaaq
# Processing Record 33 of Set 1 | cape town
# Processing Record 34 of Set 1 | ponta do sol
# Processing Record 35 of Set 1 | hithadhoo
# Processing Record 36 of Set 1 | sao felix do xingu
# Processing Record 37 of Set 1 | hasaki
# Processing Record 38 of Set 1 | ribeira grande
# Processing Record 39 of Set 1 | longyearbyen
# Processing Record 40 of Set 1 | kavaratti
# Processing Record 41 of Set 1 | mar del plata
# Processing Record 42 of Set 1 | walvis bay
# Processing Record 43 of Set 1 | dabakala
# Processing Record 44 of Set 1 | sorong
# Processing Record 45 of Set 1 | puerto ayora
# Processing Record 46 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 47 of Set 1 | fare
# Processing Record 48 of Set 1 | esperance
# Processing Record 49 of Set 1 | karratha
# Processing Record 50 of Set 1 | kapaa
# Processing Record 1 of Set 2 | avarua
# Processing Record 2 of Set 2 | victoria
# Processing Record 3 of Set 2 | boyolangu
# Processing Record 4 of Set 2 | oyama
# Processing Record 5 of Set 2 | nikolskoye
# Processing Record 6 of Set 2 | tucumcari
# Processing Record 7 of Set 2 | mahebourg
# Processing Record 8 of Set 2 | hilo
# Processing Record 9 of Set 2 | tiksi
# Processing Record 10 of Set 2 | wampusirpi
# City not found. Skipping...
# Processing Record 11 of Set 2 | torbay
# Processing Record 12 of Set 2 | hudiksvall
# Processing Record 13 of Set 2 | saint-philippe
# Processing Record 14 of Set 2 | thompson
# Processing Record 15 of Set 2 | fort frances
# Processing Record 16 of Set 2 | muros
# Processing Record 17 of Set 2 | san patricio
# Processing Record 18 of Set 2 | bubaque
# Processing Record 19 of Set 2 | lorengau
# Processing Record 20 of Set 2 | tasiilaq
# Processing Record 21 of Set 2 | provideniya
# Processing Record 22 of Set 2 | sisimiut
# Processing Record 23 of Set 2 | sindor
# Processing Record 24 of Set 2 | kaitangata
# Processing Record 25 of Set 2 | hokitika
# Processing Record 26 of Set 2 | ventspils
# Processing Record 27 of Set 2 | matagami
# Processing Record 28 of Set 2 | norman wells
# Processing Record 29 of Set 2 | bonthe
# Processing Record 30 of Set 2 | yulara
# Processing Record 31 of Set 2 | lavrentiya
# Processing Record 32 of Set 2 | nouakchott
# Processing Record 33 of Set 2 | visby
# Processing Record 34 of Set 2 | khatanga
# Processing Record 35 of Set 2 | parana
# Processing Record 36 of Set 2 | saldanha
# Processing Record 37 of Set 2 | turukhansk
# Processing Record 38 of Set 2 | cidreira
# Processing Record 39 of Set 2 | nuuk
# Processing Record 40 of Set 2 | zhitikara
# City not found. Skipping...
# Processing Record 41 of Set 2 | te anau
# Processing Record 42 of Set 2 | fortuna
# Processing Record 43 of Set 2 | arraial do cabo
# Processing Record 44 of Set 2 | port-cartier
# Processing Record 45 of Set 2 | chokurdakh
# Processing Record 46 of Set 2 | carnarvon
# Processing Record 47 of Set 2 | birmitrapur
# Processing Record 48 of Set 2 | klaksvik
# Processing Record 49 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 3 | gravdal
# Processing Record 2 of Set 3 | bambous virieux
# Processing Record 3 of Set 3 | ahipara
# Processing Record 4 of Set 3 | abreus
# Processing Record 5 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 3 | airai
# Processing Record 7 of Set 3 | taoudenni
# Processing Record 8 of Set 3 | saskylakh
# Processing Record 9 of Set 3 | benito juarez
# Processing Record 10 of Set 3 | jamestown
# Processing Record 11 of Set 3 | weinan
# Processing Record 12 of Set 3 | alexandria
# Processing Record 13 of Set 3 | sedelnikovo
# City not found. Skipping...
# Processing Record 14 of Set 3 | narsaq
# Processing Record 15 of Set 3 | jiuquan
# Processing Record 16 of Set 3 | arawa
# Processing Record 17 of Set 3 | bengkulu
# Processing Record 18 of Set 3 | qena
# Processing Record 19 of Set 3 | albany
# Processing Record 20 of Set 3 | qibili
# City not found. Skipping...
# Processing Record 21 of Set 3 | innisfail
# Processing Record 22 of Set 3 | faanui
# Processing Record 23 of Set 3 | nishihara
# Processing Record 24 of Set 3 | port elizabeth
# Processing Record 25 of Set 3 | atar
# Processing Record 26 of Set 3 | kanganpur
# Processing Record 27 of Set 3 | kaniama
# Processing Record 28 of Set 3 | yellowknife
# Processing Record 29 of Set 3 | bredasdorp
# Processing Record 30 of Set 3 | dunedin
# Processing Record 31 of Set 3 | mocambique
# City not found. Skipping...
# Processing Record 32 of Set 3 | hay river
# Processing Record 33 of Set 3 | koumac
# Processing Record 34 of Set 3 | sataua
# City not found. Skipping...
# Processing Record 35 of Set 3 | sooke
# Processing Record 36 of Set 3 | ilulissat
# Processing Record 37 of Set 3 | pacific grove
# Processing Record 38 of Set 3 | castro
# Processing Record 39 of Set 3 | inverness
# Processing Record 40 of Set 3 | villa carlos paz
# Processing Record 41 of Set 3 | portree
# Processing Record 42 of Set 3 | salalah
# Processing Record 43 of Set 3 | miri
# Processing Record 44 of Set 3 | burica
# City not found. Skipping...
# Processing Record 45 of Set 3 | olafsvik
# Processing Record 46 of Set 3 | alta floresta
# Processing Record 47 of Set 3 | bathsheba
# Processing Record 48 of Set 3 | pevek
# Processing Record 49 of Set 3 | quatre cocos
# Processing Record 50 of Set 3 | filadelfia
# Processing Record 1 of Set 4 | okhotsk
# Processing Record 2 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 4 | sovetskiy
# Processing Record 4 of Set 4 | westport
# Processing Record 5 of Set 4 | saint-georges
# Processing Record 6 of Set 4 | vilcun
# Processing Record 7 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 4 | berlevag
# Processing Record 9 of Set 4 | ondorhaan
# City not found. Skipping...
# Processing Record 10 of Set 4 | roald
# Processing Record 11 of Set 4 | georgetown
# Processing Record 12 of Set 4 | flin flon
# Processing Record 13 of Set 4 | svetlaya
# Processing Record 14 of Set 4 | mount gambier
# Processing Record 15 of Set 4 | kruisfontein
# Processing Record 16 of Set 4 | cabra
# Processing Record 17 of Set 4 | husavik
# Processing Record 18 of Set 4 | dhidhdhoo
# Processing Record 19 of Set 4 | udachnyy
# Processing Record 20 of Set 4 | fonte boa
# Processing Record 21 of Set 4 | pisco
# Processing Record 22 of Set 4 | marystown
# Processing Record 23 of Set 4 | tuatapere
# Processing Record 24 of Set 4 | carndonagh
# Processing Record 25 of Set 4 | kenora
# Processing Record 26 of Set 4 | jiroft
# City not found. Skipping...
# Processing Record 27 of Set 4 | cumaribo
# City not found. Skipping...
# Processing Record 28 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 29 of Set 4 | leningradskiy
# Processing Record 30 of Set 4 | saint george
# Processing Record 31 of Set 4 | carlibaba
# Processing Record 32 of Set 4 | harper
# Processing Record 33 of Set 4 | bozoum
# Processing Record 34 of Set 4 | ambon
# Processing Record 35 of Set 4 | dire
# Processing Record 36 of Set 4 | morgan city
# Processing Record 37 of Set 4 | belyy yar
# Processing Record 38 of Set 4 | tumut
# Processing Record 39 of Set 4 | traverse city
# Processing Record 40 of Set 4 | nerchinskiy zavod
# Processing Record 41 of Set 4 | evensk
# Processing Record 42 of Set 4 | valparaiso
# Processing Record 43 of Set 4 | severo-kurilsk
# Processing Record 44 of Set 4 | bilibino
# Processing Record 45 of Set 4 | slave lake
# Processing Record 46 of Set 4 | lagoa
# Processing Record 47 of Set 4 | omboue
# Processing Record 48 of Set 4 | augusto correa
# Processing Record 49 of Set 4 | kargopol
# Processing Record 50 of Set 4 | shanhetun
# Processing Record 1 of Set 5 | kallithea
# Processing Record 2 of Set 5 | tutoia
# Processing Record 3 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 5 | vestmannaeyjar
# Processing Record 6 of Set 5 | rozivka
# Processing Record 7 of Set 5 | romny
# Processing Record 8 of Set 5 | remanso
# Processing Record 9 of Set 5 | byron bay
# Processing Record 10 of Set 5 | souillac
# Processing Record 11 of Set 5 | cabo san lucas
# Processing Record 12 of Set 5 | los llanos de aridane
# Processing Record 13 of Set 5 | jumla
# Processing Record 14 of Set 5 | terney
# Processing Record 15 of Set 5 | tura
# Processing Record 16 of Set 5 | chuy
# Processing Record 17 of Set 5 | carbondale
# Processing Record 18 of Set 5 | aljezur
# Processing Record 19 of Set 5 | lasa
# Processing Record 20 of Set 5 | jarocin
# Processing Record 21 of Set 5 | lagdo
# Processing Record 22 of Set 5 | opuwo
# Processing Record 23 of Set 5 | melfi
# Processing Record 24 of Set 5 | ulvik
# Processing Record 25 of Set 5 | baruun-urt
# Processing Record 26 of Set 5 | kabanjahe
# Processing Record 27 of Set 5 | eyl
# Processing Record 28 of Set 5 | tuktoyaktuk
# Processing Record 29 of Set 5 | kachiry
# Processing Record 30 of Set 5 | yar-sale
# Processing Record 31 of Set 5 | carutapera
# Processing Record 32 of Set 5 | najran
# Processing Record 33 of Set 5 | broken hill
# Processing Record 34 of Set 5 | nome
# Processing Record 35 of Set 5 | upernavik
# Processing Record 36 of Set 5 | sambava
# Processing Record 37 of Set 5 | palestine
# Processing Record 38 of Set 5 | virginia beach
# Processing Record 39 of Set 5 | saint-joseph
# Processing Record 40 of Set 5 | krasnoselkup
# Processing Record 41 of Set 5 | antalaha
# Processing Record 42 of Set 5 | balykshi
# Processing Record 43 of Set 5 | kavieng
# Processing Record 44 of Set 5 | padang
# Processing Record 45 of Set 5 | muravlenko
# Processing Record 46 of Set 5 | oktyabrskoye
# Processing Record 47 of Set 5 | dali
# Processing Record 48 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 49 of Set 5 | egvekinot
# Processing Record 50 of Set 5 | ancud
# Processing Record 1 of Set 6 | high level
# Processing Record 2 of Set 6 | santa cruz de tenerife
# Processing Record 3 of Set 6 | tari
# Processing Record 4 of Set 6 | carlsbad
# Processing Record 5 of Set 6 | ishurdi
# Processing Record 6 of Set 6 | caravelas
# Processing Record 7 of Set 6 | mponela
# Processing Record 8 of Set 6 | saint anthony
# Processing Record 9 of Set 6 | mergui
# City not found. Skipping...
# Processing Record 10 of Set 6 | krasnovishersk
# Processing Record 11 of Set 6 | ostrovnoy
# Processing Record 12 of Set 6 | mathathane
# Processing Record 13 of Set 6 | harstad
# Processing Record 14 of Set 6 | ayorou
# Processing Record 15 of Set 6 | maloshuyka
# City not found. Skipping...
# Processing Record 16 of Set 6 | aklavik
# Processing Record 17 of Set 6 | borama
# City not found. Skipping...
# Processing Record 18 of Set 6 | peniche
# Processing Record 19 of Set 6 | tuzamapan
# Processing Record 20 of Set 6 | guerrero negro
# Processing Record 21 of Set 6 | mount isa
# Processing Record 22 of Set 6 | la vista
# Processing Record 23 of Set 6 | ust-omchug
# Processing Record 24 of Set 6 | itarema
# Processing Record 25 of Set 6 | port-gentil
# Processing Record 26 of Set 6 | maceio
# Processing Record 27 of Set 6 | dolbeau
# City not found. Skipping...
# Processing Record 28 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 29 of Set 6 | trincomalee
# Processing Record 30 of Set 6 | calama
# Processing Record 31 of Set 6 | high rock
# Processing Record 32 of Set 6 | buchanan
# Processing Record 33 of Set 6 | vardo
# Processing Record 34 of Set 6 | verkhnevilyuysk
# Processing Record 35 of Set 6 | anadyr
# Processing Record 36 of Set 6 | inhambane
# Processing Record 37 of Set 6 | verkh-suetka
# Processing Record 38 of Set 6 | mokhotlong
# Processing Record 39 of Set 6 | katobu
# Processing Record 40 of Set 6 | chipinge
# Processing Record 41 of Set 6 | namikupa
# Processing Record 42 of Set 6 | flinders
# Processing Record 43 of Set 6 | port hawkesbury
# Processing Record 44 of Set 6 | quimper
# Processing Record 45 of Set 6 | oranjestad
# Processing Record 46 of Set 6 | saint-pierre
# Processing Record 47 of Set 6 | funtua
# Processing Record 48 of Set 6 | bambanglipuro
# Processing Record 49 of Set 6 | nanortalik
# Processing Record 50 of Set 6 | coacotla
# Processing Record 1 of Set 7 | sucua
# Processing Record 2 of Set 7 | kamenka
# Processing Record 3 of Set 7 | namatanai
# Processing Record 4 of Set 7 | vao
# Processing Record 5 of Set 7 | konnur
# Processing Record 6 of Set 7 | sao filipe
# Processing Record 7 of Set 7 | axim
# Processing Record 8 of Set 7 | san policarpo
# Processing Record 9 of Set 7 | matamoros
# Processing Record 10 of Set 7 | pangnirtung
# Processing Record 11 of Set 7 | aguilas
# Processing Record 12 of Set 7 | dawei
# Processing Record 13 of Set 7 | itainopolis
# Processing Record 14 of Set 7 | whitehorse
# Processing Record 15 of Set 7 | nemuro
# Processing Record 16 of Set 7 | karasuk
# Processing Record 17 of Set 7 | cancun
# Processing Record 18 of Set 7 | tigil
# Processing Record 19 of Set 7 | maralal
# Processing Record 20 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 7 | bemidji
# Processing Record 22 of Set 7 | tromso
# Processing Record 23 of Set 7 | tortoli
# Processing Record 24 of Set 7 | cockburn town
# Processing Record 25 of Set 7 | toora-khem
# Processing Record 26 of Set 7 | fiche
# Processing Record 27 of Set 7 | meshcherino
# Processing Record 28 of Set 7 | mogadishu
# Processing Record 29 of Set 7 | jha jha
# Processing Record 30 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 31 of Set 7 | roma
# Processing Record 32 of Set 7 | kodiak
# Processing Record 33 of Set 7 | samarai
# Processing Record 34 of Set 7 | lebu
# Processing Record 35 of Set 7 | ponta delgada
# Processing Record 36 of Set 7 | vila velha
# Processing Record 37 of Set 7 | port hedland
# Processing Record 38 of Set 7 | hambantota
# Processing Record 39 of Set 7 | alice springs
# Processing Record 40 of Set 7 | talaya
# Processing Record 41 of Set 7 | vaitape
# Processing Record 42 of Set 7 | katsuura
# Processing Record 43 of Set 7 | elat
# Processing Record 44 of Set 7 | xushan
# Processing Record 45 of Set 7 | wabana
# Processing Record 46 of Set 7 | shieli
# Processing Record 47 of Set 7 | marienburg
# Processing Record 48 of Set 7 | kurilsk
# Processing Record 49 of Set 7 | sohag
# Processing Record 50 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 8 | pendleton
# Processing Record 2 of Set 8 | jinchengjiang
# City not found. Skipping...
# Processing Record 3 of Set 8 | tera
# Processing Record 4 of Set 8 | at-bashi
# Processing Record 5 of Set 8 | muchkapskiy
# Processing Record 6 of Set 8 | yerbogachen
# Processing Record 7 of Set 8 | batagay-alyta
# Processing Record 8 of Set 8 | lazaro cardenas
# Processing Record 9 of Set 8 | duz
# City not found. Skipping...
# Processing Record 10 of Set 8 | new waterford
# Processing Record 11 of Set 8 | port hardy
# Processing Record 12 of Set 8 | port keats
# Processing Record 13 of Set 8 | kenai
# Processing Record 14 of Set 8 | bethel
# Processing Record 15 of Set 8 | ahuimanu
# Processing Record 16 of Set 8 | imbituba
# Processing Record 17 of Set 8 | ngunguru
# Processing Record 18 of Set 8 | hirara
# Processing Record 19 of Set 8 | hare bay
# Processing Record 20 of Set 8 | amambai
# Processing Record 21 of Set 8 | kargasok
# Processing Record 22 of Set 8 | rawson
# Processing Record 23 of Set 8 | urengoy
# Processing Record 24 of Set 8 | sergeyevka
# Processing Record 25 of Set 8 | newton
# Processing Record 26 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 8 | turayf
# Processing Record 28 of Set 8 | moose factory
# Processing Record 29 of Set 8 | san vicente
# Processing Record 30 of Set 8 | atikokan
# Processing Record 31 of Set 8 | xinzhou
# Processing Record 32 of Set 8 | hualmay
# Processing Record 33 of Set 8 | tiarei
# Processing Record 34 of Set 8 | sandpoint
# Processing Record 35 of Set 8 | boa vista
# Processing Record 36 of Set 8 | galesong
# Processing Record 37 of Set 8 | komsomolskiy
# Processing Record 38 of Set 8 | geraldton
# Processing Record 39 of Set 8 | mozarlandia
# Processing Record 40 of Set 8 | xunchang
# Processing Record 41 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 8 | boueni
# Processing Record 43 of Set 8 | kargala
# Processing Record 44 of Set 8 | macae
# Processing Record 45 of Set 8 | wahiawa
# Processing Record 46 of Set 8 | ingham
# Processing Record 47 of Set 8 | lianran
# Processing Record 48 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 8 | coihaique
# Processing Record 50 of Set 8 | uyemskiy
# Processing Record 1 of Set 9 | shelburne
# Processing Record 2 of Set 9 | mayor pablo lagerenza
# Processing Record 3 of Set 9 | neuquen
# Processing Record 4 of Set 9 | cafelandia
# Processing Record 5 of Set 9 | gat
# Processing Record 6 of Set 9 | hami
# Processing Record 7 of Set 9 | morecambe
# Processing Record 8 of Set 9 | darhan
# Processing Record 9 of Set 9 | bacuit
# City not found. Skipping...
# Processing Record 10 of Set 9 | egersund
# Processing Record 11 of Set 9 | farafangana
# Processing Record 12 of Set 9 | kokopo
# Processing Record 13 of Set 9 | palana
# Processing Record 14 of Set 9 | kalmunai
# Processing Record 15 of Set 9 | manaus
# Processing Record 16 of Set 9 | shaoxing
# Processing Record 17 of Set 9 | yaya
# Processing Record 18 of Set 9 | mirnyy
# Processing Record 19 of Set 9 | cukai
# Processing Record 20 of Set 9 | general roca
# Processing Record 21 of Set 9 | griffith
# Processing Record 22 of Set 9 | valday
# Processing Record 23 of Set 9 | tobermory
# Processing Record 24 of Set 9 | pavlovsk
# Processing Record 25 of Set 9 | ormos korthiou
# City not found. Skipping...
# Processing Record 26 of Set 9 | zyryanka
# Processing Record 27 of Set 9 | mandalgovi
# Processing Record 28 of Set 9 | tanout
# Processing Record 29 of Set 9 | puerto narino
# Processing Record 30 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 9 | clyde river
# Processing Record 32 of Set 9 | san luis
# Processing Record 33 of Set 9 | mackay
# Processing Record 34 of Set 9 | altamont
# Processing Record 35 of Set 9 | ilo
# Processing Record 36 of Set 9 | zhangye
# Processing Record 37 of Set 9 | neiafu
# Processing Record 38 of Set 9 | gogrial
# Processing Record 39 of Set 9 | asosa
# Processing Record 40 of Set 9 | porto velho
# Processing Record 41 of Set 9 | ozernovskiy
# Processing Record 42 of Set 9 | pochutla
# Processing Record 43 of Set 9 | chapais
# Processing Record 44 of Set 9 | newport
# Processing Record 45 of Set 9 | sao joao da barra
# Processing Record 46 of Set 9 | talara
# Processing Record 47 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 9 | vytegra
# Processing Record 49 of Set 9 | japura
# Processing Record 50 of Set 9 | lompoc
# Processing Record 1 of Set 10 | constitucion
# Processing Record 2 of Set 10 | sur
# Processing Record 3 of Set 10 | pecanha
# Processing Record 4 of Set 10 | kahului
# Processing Record 5 of Set 10 | tshikapa
# Processing Record 6 of Set 10 | hofn
# Processing Record 7 of Set 10 | srednekolymsk
# Processing Record 8 of Set 10 | lola
# Processing Record 9 of Set 10 | cherskiy
# Processing Record 10 of Set 10 | maniitsoq
# Processing Record 11 of Set 10 | mordovo
# Processing Record 12 of Set 10 | la ronge
# Processing Record 13 of Set 10 | marshalltown
# Processing Record 14 of Set 10 | buea
# Processing Record 15 of Set 10 | faya
# Processing Record 16 of Set 10 | saint-francois
# Processing Record 17 of Set 10 | wukari
# Processing Record 18 of Set 10 | mahibadhoo
# Processing Record 19 of Set 10 | scottsburgh
# City not found. Skipping...
# Processing Record 20 of Set 10 | manhattan
# Processing Record 21 of Set 10 | marsh harbour
# Processing Record 22 of Set 10 | mataram
# Processing Record 23 of Set 10 | puerto quijarro
# Processing Record 24 of Set 10 | khani
# Processing Record 25 of Set 10 | whyalla
# Processing Record 26 of Set 10 | srisailam
# Processing Record 27 of Set 10 | ostrovskoye
# Processing Record 28 of Set 10 | dabhol
# Processing Record 29 of Set 10 | tilichiki
# Processing Record 30 of Set 10 | lata
# Processing Record 31 of Set 10 | cervo
# Processing Record 32 of Set 10 | senaki
# Processing Record 33 of Set 10 | mahajanga
# Processing Record 34 of Set 10 | pozo colorado
# Processing Record 35 of Set 10 | zhigansk
# Processing Record 36 of Set 10 | patulul
# Processing Record 37 of Set 10 | samoded
# Processing Record 38 of Set 10 | meulaboh
# Processing Record 39 of Set 10 | charters towers
# Processing Record 40 of Set 10 | alamogordo
# Processing Record 41 of Set 10 | gazli
# Processing Record 42 of Set 10 | bakchar
# Processing Record 43 of Set 10 | bowen
# Processing Record 44 of Set 10 | tocopilla
# Processing Record 45 of Set 10 | namibe
# Processing Record 46 of Set 10 | luanda
# Processing Record 47 of Set 10 | totness
# Processing Record 48 of Set 10 | gospic
# Processing Record 49 of Set 10 | yingshang
# City not found. Skipping...
# Processing Record 50 of Set 10 | akdepe
# Processing Record 1 of Set 11 | porto torres
# Processing Record 2 of Set 11 | miranorte
# City not found. Skipping...
# Processing Record 3 of Set 11 | itaqui
# Processing Record 4 of Set 11 | pinheiro machado
# Processing Record 5 of Set 11 | kununurra
# Processing Record 6 of Set 11 | tabialan
# City not found. Skipping...
# Processing Record 7 of Set 11 | dingle
# Processing Record 8 of Set 11 | shelui
# Processing Record 9 of Set 11 | cap malheureux
# Processing Record 10 of Set 11 | muisne
# Processing Record 11 of Set 11 | rocha
# Processing Record 12 of Set 11 | olavarria
# Processing Record 13 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 14 of Set 11 | codrington
# Processing Record 15 of Set 11 | vila franca do campo
# Processing Record 16 of Set 11 | stornoway
# Processing Record 17 of Set 11 | craig
# Processing Record 18 of Set 11 | elizabeth city
# Processing Record 19 of Set 11 | mayo
# Processing Record 20 of Set 11 | talavera
# Processing Record 21 of Set 11 | robe
# Processing Record 22 of Set 11 | jahrom
# City not found. Skipping...
# Processing Record 23 of Set 11 | key west
# Processing Record 24 of Set 11 | cap-aux-meules
# Processing Record 25 of Set 11 | kataysk
# Processing Record 26 of Set 11 | lancaster
# Processing Record 27 of Set 11 | moron
# Processing Record 28 of Set 11 | tupancireta
# Processing Record 29 of Set 11 | garmsar
# Processing Record 30 of Set 11 | tezu
# Processing Record 31 of Set 11 | qiongshan
# Processing Record 32 of Set 11 | altay
# Processing Record 33 of Set 11 | agadez
# Processing Record 34 of Set 11 | camacha
# Processing Record 35 of Set 11 | sinegorskiy
# Processing Record 36 of Set 11 | qui nhon
# Processing Record 37 of Set 11 | makakilo city
# Processing Record 38 of Set 11 | port blair
# Processing Record 39 of Set 11 | dauriya
# Processing Record 40 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 41 of Set 11 | drahovo
# Processing Record 42 of Set 11 | surgut
# Processing Record 43 of Set 11 | fort nelson
# Processing Record 44 of Set 11 | ternate
# Processing Record 45 of Set 11 | ulaanbaatar
# Processing Record 46 of Set 11 | iqaluit
# Processing Record 47 of Set 11 | beruwala
# Processing Record 48 of Set 11 | sivaki
# Processing Record 49 of Set 11 | crotone
# Processing Record 50 of Set 11 | asau
# Processing Record 1 of Set 12 | luderitz
# Processing Record 2 of Set 12 | karuri
# Processing Record 3 of Set 12 | herat
# Processing Record 4 of Set 12 | abong mbang
# Processing Record 5 of Set 12 | luau
# Processing Record 6 of Set 12 | mitu
# Processing Record 7 of Set 12 | drayton valley
# Processing Record 8 of Set 12 | broome
# Processing Record 9 of Set 12 | nosy varika
# Processing Record 10 of Set 12 | haradok
# Processing Record 11 of Set 12 | kuching
# Processing Record 12 of Set 12 | ixtapa
# Processing Record 13 of Set 12 | yeppoon
# Processing Record 14 of Set 12 | fukue
# Processing Record 15 of Set 12 | warrington
# Processing Record 16 of Set 12 | stephenville
# Processing Record 17 of Set 12 | la libertad
# Processing Record 18 of Set 12 | yagodnoye
# Processing Record 19 of Set 12 | juneau
# Processing Record 20 of Set 12 | gemena
# Processing Record 21 of Set 12 | miracema do tocantins
# Processing Record 22 of Set 12 | jawhar
# Processing Record 23 of Set 12 | maragogi
# Processing Record 24 of Set 12 | dickinson
# Processing Record 25 of Set 12 | lienz
# Processing Record 26 of Set 12 | redding
# Processing Record 27 of Set 12 | marsaxlokk
# Processing Record 28 of Set 12 | adre
# Processing Record 29 of Set 12 | riyadh
# Processing Record 30 of Set 12 | tupik
# Processing Record 31 of Set 12 | alibag
# Processing Record 32 of Set 12 | alofi
# Processing Record 33 of Set 12 | atasu
# Processing Record 34 of Set 12 | thames
# Processing Record 35 of Set 12 | kelvington
# Processing Record 36 of Set 12 | binga
# Processing Record 37 of Set 12 | ao luk
# City not found. Skipping...
# Processing Record 38 of Set 12 | kieta
# Processing Record 39 of Set 12 | egra
# Processing Record 40 of Set 12 | terre haute
# Processing Record 41 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 42 of Set 12 | crucea
# Processing Record 43 of Set 12 | noumea
# Processing Record 44 of Set 12 | cayenne
# Processing Record 45 of Set 12 | north platte
# Processing Record 46 of Set 12 | hvide sande
# Processing Record 47 of Set 12 | yuli
# Processing Record 48 of Set 12 | dunda
# Processing Record 49 of Set 12 | gatesville
# Processing Record 50 of Set 12 | port augusta
# Processing Record 1 of Set 13 | havoysund
# Processing Record 2 of Set 13 | biskamzha
# Processing Record 3 of Set 13 | nantucket
# Processing Record 4 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 5 of Set 13 | doha
# Processing Record 6 of Set 13 | beloha
# Processing Record 7 of Set 13 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 13 | bataipora
# Processing Record 9 of Set 13 | sitka
# Processing Record 10 of Set 13 | cheremnoye
# Processing Record 11 of Set 13 | bastia
# Processing Record 12 of Set 13 | linqiong
# Processing Record 13 of Set 13 | half moon bay
# Processing Record 14 of Set 13 | kalabo
# Processing Record 15 of Set 13 | plouzane
# Processing Record 16 of Set 13 | kolondieba
# Processing Record 17 of Set 13 | bairiki
# Processing Record 18 of Set 13 | bucerias
# Processing Record 19 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 20 of Set 13 | leh
# Processing Record 21 of Set 13 | kotelnich
# Processing Record 22 of Set 13 | nanakuli
# Processing Record 23 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 24 of Set 13 | trairi
# Processing Record 25 of Set 13 | prieska
# Processing Record 26 of Set 13 | kakamega
# Processing Record 27 of Set 13 | maarianhamina
# Processing Record 28 of Set 13 | katherine
# Processing Record 29 of Set 13 | bandarbeyla
# Processing Record 30 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 13 | portland
# Processing Record 32 of Set 13 | peterhead
# Processing Record 33 of Set 13 | kidal
# Processing Record 34 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 35 of Set 13 | de aar
# Processing Record 36 of Set 13 | turbat
# Processing Record 37 of Set 13 | khash
# Processing Record 38 of Set 13 | ubinskoye
# Processing Record 39 of Set 13 | dukat
# Processing Record 40 of Set 13 | nicoya
# Processing Record 41 of Set 13 | constantine
# Processing Record 42 of Set 13 | tonekabon
# Processing Record 43 of Set 13 | tabarqah
# City not found. Skipping...
# Processing Record 44 of Set 13 | boende
# Processing Record 45 of Set 13 | homer
# Processing Record 46 of Set 13 | brae
# Processing Record 47 of Set 13 | aksarka
# Processing Record 48 of Set 13 | campbellton
# Processing Record 49 of Set 13 | tongliao
# Processing Record 50 of Set 13 | beaufort
# Processing Record 1 of Set 14 | redmond
# Processing Record 2 of Set 14 | cururupu
# Processing Record 3 of Set 14 | yatou
# Processing Record 4 of Set 14 | quang ngai
# Processing Record 5 of Set 14 | santa isabel do rio negro
# Processing Record 6 of Set 14 | fomboni
# Processing Record 7 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 8 of Set 14 | ascension
# Processing Record 9 of Set 14 | manggar
# Processing Record 10 of Set 14 | emba
# Processing Record 11 of Set 14 | acapulco
# Processing Record 12 of Set 14 | kurikka
# Processing Record 13 of Set 14 | waitati
# Processing Record 14 of Set 14 | celestun
# Processing Record 15 of Set 14 | kholtoson
# Processing Record 16 of Set 14 | the valley
# Processing Record 17 of Set 14 | kyzyl-suu
# Processing Record 18 of Set 14 | bayanday
# Processing Record 19 of Set 14 | uniontown
# Processing Record 20 of Set 14 | santiago
# Processing Record 21 of Set 14 | bolkhov
# Processing Record 22 of Set 14 | chivilcoy
# Processing Record 23 of Set 14 | seal beach
# Processing Record 24 of Set 14 | marzuq
# Processing Record 25 of Set 14 | mayskiy
# Processing Record 26 of Set 14 | severo-yeniseyskiy
# Processing Record 27 of Set 14 | bahia honda
# Processing Record 28 of Set 14 | nioki
# Processing Record 29 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 30 of Set 14 | huangmei
# Processing Record 31 of Set 14 | tucuman
# Processing Record 32 of Set 14 | iskateley
# Processing Record 33 of Set 14 | ranong
# Processing Record 34 of Set 14 | bend
# Processing Record 35 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 36 of Set 14 | les cayes
# Processing Record 37 of Set 14 | shingu
# Processing Record 38 of Set 14 | almaznyy
# Processing Record 39 of Set 14 | phan thiet
# Processing Record 40 of Set 14 | eureka
# Processing Record 41 of Set 14 | zarechnyy
# Processing Record 42 of Set 14 | manavgat
# Processing Record 43 of Set 14 | carballo
# Processing Record 44 of Set 14 | sibolga
# Processing Record 45 of Set 14 | tual
# Processing Record 46 of Set 14 | sinnai
# Processing Record 47 of Set 14 | abu samrah
# Processing Record 48 of Set 14 | shache
# Processing Record 49 of Set 14 | jackson
# Processing Record 50 of Set 14 | lapeer
# Processing Record 1 of Set 15 | yanan
# City not found. Skipping...
# Processing Record 2 of Set 15 | garoua
# Processing Record 3 of Set 15 | orbetello
# Processing Record 4 of Set 15 | svetlyy
# Processing Record 5 of Set 15 | mugreyevskiy
# City not found. Skipping...
# Processing Record 6 of Set 15 | labuhan
# Processing Record 7 of Set 15 | nabire
# Processing Record 8 of Set 15 | shuiji
# Processing Record 9 of Set 15 | vargashi
# Processing Record 10 of Set 15 | sinjar
# Processing Record 11 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 12 of Set 15 | gananoque
# Processing Record 13 of Set 15 | coquimbo
# Processing Record 14 of Set 15 | barkly west
# Processing Record 15 of Set 15 | gumdag
# Processing Record 16 of Set 15 | hoi an
# Processing Record 17 of Set 15 | naberera
# Processing Record 18 of Set 15 | contamana
# Processing Record 19 of Set 15 | ziezmariai
# Processing Record 20 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 21 of Set 15 | jiaojiang
# Processing Record 22 of Set 15 | jishou
# Processing Record 23 of Set 15 | merauke
# Processing Record 24 of Set 15 | puro
# Processing Record 25 of Set 15 | honiara
# Processing Record 26 of Set 15 | bonavista
# Processing Record 27 of Set 15 | minab
# Processing Record 28 of Set 15 | jieshi
# Processing Record 29 of Set 15 | yol
# Processing Record 30 of Set 15 | richards bay
# Processing Record 31 of Set 15 | candolim
# Processing Record 32 of Set 15 | tautira
# Processing Record 33 of Set 15 | antanifotsy
# Processing Record 34 of Set 15 | rosetta
# Processing Record 35 of Set 15 | khandyga
# Processing Record 36 of Set 15 | tres arroyos
# Processing Record 37 of Set 15 | watsa
# Processing Record 38 of Set 15 | mokolo
# Processing Record 39 of Set 15 | san carlos
# Processing Record 40 of Set 15 | jawa
# Processing Record 41 of Set 15 | nauta
# Processing Record 42 of Set 15 | minsk
# Processing Record 43 of Set 15 | sabinas
# Processing Record 44 of Set 15 | wanning
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Bluff -46.6000  168.3333     54.77        83          92
# 1     Busselton -33.6500  115.3333     64.00        99          98
# 2       Mataura -46.1927  168.8643     53.46        80          98
# 3  Presque Isle  46.6811  -68.0159     26.60        50           1
# 4    Butaritari   3.0707  172.7902     80.87        80         100
# 5       Ushuaia -54.8000  -68.3000     59.00        47          40
# 6   East London -33.0153   27.9116     71.60        88          40
# 7       Sakakah  29.9697   40.2064     55.40        62           0
# 8       Rikitea -23.1203 -134.9692     77.32        72          91
# 9        Hobart -42.8794  147.3294     53.60        58          40
#
#    Wind Speed Country Current Description
# 0        5.39      NZ     overcast clouds
# 1        1.01      AU     overcast clouds
# 2        1.95      NZ     overcast clouds
# 3        9.22      US           clear sky
# 4       20.38      KI     overcast clouds
# 5       12.66      AR    scattered clouds
# 6        3.44      ZA          light rain
# 7        6.91      SA           clear sky
# 8       12.30      PF     overcast clouds
# 9       11.50      AU    scattered clouds

# %%
# Reorder Columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Bluff      NZ -46.6000  168.3333     54.77        83          92
# 1     Busselton      AU -33.6500  115.3333     64.00        99          98
# 2       Mataura      NZ -46.1927  168.8643     53.46        80          98
# 3  Presque Isle      US  46.6811  -68.0159     26.60        50           1
# 4    Butaritari      KI   3.0707  172.7902     80.87        80         100
# 5       Ushuaia      AR -54.8000  -68.3000     59.00        47          40
# 6   East London      ZA -33.0153   27.9116     71.60        88          40
# 7       Sakakah      SA  29.9697   40.2064     55.40        62           0
# 8       Rikitea      PF -23.1203 -134.9692     77.32        72          91
# 9        Hobart      AU -42.8794  147.3294     53.60        58          40
#
#    Wind Speed Current Description
# 0        5.39     overcast clouds
# 1        1.01     overcast clouds
# 2        1.95     overcast clouds
# 3        9.22           clear sky
# 4       20.38     overcast clouds
# 5       12.66    scattered clouds
# 6        3.44          light rain
# 7        6.91           clear sky
# 8       12.30     overcast clouds
# 9       11.50    scattered clouds

# %%
# Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"
# Export the city_data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
